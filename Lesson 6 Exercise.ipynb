# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima_model import ARIMA
from pandas import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/Users/sxf1q7d/Google Drive/Deep_Learning_Time_Series/sales-of-shampoo-over-a-three-ye.csv',header=0, index_col=0)
data.head()
# Out:
#        Sales of shampoo over a three year period
# Month
# 1.00                                       266.0
# 2.00                                       145.9
# 3.00                                       183.1
# 4.00                                       119.3
# 5.00                                       180.3

# %%
data.plot()
plt.show()

# %%
plt.acorr(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-48de6078bddb> in <module>()
# ----> 1 plt.acorr(data)
#       2 plt.show()
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in acorr(x, hold, data, **kwargs)
#    2626                       mplDeprecation)
#    2627     try:
# -> 2628         ret = ax.acorr(x, data=data, **kwargs)
#    2629     finally:
#    2630         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in acorr(self, x, **kwargs)
#    1839         if "hold" in kwargs:
#    1840             warnings.warn("the 'hold' kwarg is deprecated", mplDeprecation)
# -> 1841         return self.xcorr(x, x, **kwargs)
#    1842
#    1843     @_preprocess_data(replace_names=["x", "y"], label_namer="y")
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in xcorr(self, x, y, normed, detrend, usevlines, maxlags, **kwargs)
#    1910         y = detrend(np.asarray(y))
#    1911
# -> 1912         correls = np.correlate(x, y, mode=2)
#    1913
#    1914         if normed:
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in correlate(a, v, mode)
#     936     """
#     937     mode = _mode_from_name(mode)
# --> 938     return multiarray.correlate2(a, v, mode)
#     939
#     940
#
# ValueError: object too deep for desired array

# %% [markdown]
# # Model

# %%
data.dropna(0)
data = np.asarray(data)
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-54bfb6c37544> in <module>()
# ----> 1 data.dropna(0)
#       2 data = np.asarray(data)
#       3 data
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dropna'

# %%
model = ARIMA(data, order=(5,1,0))
model_fit = model.fit()
model_fit.info()
# print(model_fit.summary())
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-6-9b743f5b29bb> in <module>()
#       1 model = ARIMA(data, order=(5,1,0))
# ----> 2 model_fit = model.fit()
#       3 model_fit.info()
#       4 # print(model_fit.summary())
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1155                                            method, transparams, solver,
#    1156                                            maxiter, full_output, disp,
# -> 1157                                            callback, start_ar_lags, **kwargs)
#    1158         normalized_cov_params = None  # TODO: fix this?
#    1159         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     944         else:  # estimate starting parameters
#     945             start_params = self._fit_start_params((k_ar, k_ma, k), method,
# --> 946                                                   start_ar_lags)
#     947
#     948         if transparams:  # transform initial parameters to ensure invertibility
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params(self, order, method, start_ar_lags)
#     560             func = lambda params: -self.loglike_css(params)
#     561             #start_params = [.1]*(k_ar+k_ma+k_exog) # different one for k?
# --> 562             start_params = self._fit_start_params_hr(order, start_ar_lags)
#     563             if self.transparams:
#     564                 start_params = self._invtransparams(start_params)
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params_hr(self, order, start_ar_lags)
#     537
#     538         # check AR coefficients
# --> 539         if p and not np.all(np.abs(np.roots(np.r_[1, -start_params[k:k + p]]
#     540                                             )) < 1):
#     541             raise ValueError("The computed initial AR coefficients are not "
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/polynomial.py in roots(p)
#     227         A = diag(NX.ones((N-2,), p.dtype), -1)
#     228         A[0,:] = -p[1:] / p[0]
# --> 229         roots = eigvals(A)
#     230     else:
#     231         roots = NX.array([])
#
# /anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in eigvals(a)
#     902     _assertRankAtLeast2(a)
#     903     _assertNdSquareness(a)
# --> 904     _assertFinite(a)
#     905     t, result_t = _commonType(a)
#     906
#
# /anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in _assertFinite(*arrays)
#     214     for a in arrays:
#     215         if not (isfinite(a).all()):
# --> 216             raise LinAlgError("Array must not contain infs or NaNs")
#     217
#     218 def _isEmpty2d(arr):
#
# LinAlgError: Array must not contain infs or NaNs
